# %% [markdown]
# # Descriptive Statistics and Python Implementation😧

# %% [raw]
# Write a Jupyter Notebook explaining all the Descriptive Statistics.
# Mean
# Median
# Mode
# Variance
# Standard Deviation
# Correlation
# Normal Distribution (use references)
# Feature of Normal Distribution
# Positively Skewed & Negatively Skewed Normal Distribution
# Effect on Mean, Median and Mode due to Skewness
# Explain QQ Plot and show the implementation of the same
# Explain Box Cox and show the implementation of the same
#
# Explain each topic (mentioned above) with the help of images, code examples (with and without library functions) and formulas (written using LaTeX)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns 
import math
import scipy.stats as stats

# %%
data = pd.read_csv("data (decriptive an).csv")

# %%
data.head(10)
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
# 5            14000              8000                  2                0
# 6            15000             16000                  3            35000
# 7            18000             20000                  5             8000
# 8            19000              9000                  2                0
# 9            20000              9000                  4                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# ...

# %%
data.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
data.shape
# Out:
# (50, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# ## What is Mean?
# * Mean is an essential concept in mathematics and statistics. The mean is the average or the most common value in a collection of numbers.
#
# * In statistics, it is a measure of central tendency of a probability distribution along median and mode. It is also referred to as an expected value.

# %% [markdown]
# ### Mean Formula

# %% [markdown]
# $$A =  \frac{1}{n}\sum_{i=1}^{n} a{i} $$
#
# $
# A	=	arithmetic \ mean\\
# n	=	number \ of \ values\\
# a_i	=	data \ set \ values\\
# $

# %%
# Finding mean for the given data set

# %% [markdown]
# #### Mean with inbulit function

# %%
data_mean = {'Mthly_HH_Income':data['Mthly_HH_Income'].mean(),'Mthly_HH_Expense':data['Mthly_HH_Expense'].mean(),
   'Emi_or_Rent_Amt':data['Emi_or_Rent_Amt'].mean(),'Annual_HH_Income':data['Annual_HH_Income'].mean()}

# %%
data_mean
# Out:
# {'Mthly_HH_Income': 41558.0,
#  'Mthly_HH_Expense': 18818.0,
#  'Emi_or_Rent_Amt': 3060.0,
#  'Annual_HH_Income': 490019.04}

# %%
pd.DataFrame.from_dict(data_mean,orient="index",columns=['mean'])
# Out:
#                        mean
# Mthly_HH_Income    41558.00
# Mthly_HH_Expense   18818.00
# Emi_or_Rent_Amt     3060.00
# Annual_HH_Income  490019.04

# %% [markdown]
# #### Mean witout inbuilt function

# %%
Mthly_HH_Income = sum(data['Mthly_HH_Income'])/len(data['Mthly_HH_Income'])
Mthly_HH_Expense = sum(data['Mthly_HH_Expense'])/len(data['Mthly_HH_Expense'])
Emi_or_Rent_Amt = sum(data['Emi_or_Rent_Amt'])/len(data['Emi_or_Rent_Amt'])
Annual_HH_Income = sum(data['Annual_HH_Income'])/len(data['Annual_HH_Income'])
data1 = [Mthly_HH_Income,Mthly_HH_Expense,Emi_or_Rent_Amt,Annual_HH_Income]
names =  ['Mthly_HH_Income','Mthly_HH_Expense','Emi_or_Rent_Amt','Annual_HH_Income']

# %%
pd.DataFrame(data1,index=names,columns=['mean'])
# Out:
#                        mean
# Mthly_HH_Income    41558.00
# Mthly_HH_Expense   18818.00
# Emi_or_Rent_Amt     3060.00
# Annual_HH_Income  490019.04

# %% [markdown]
# ## What is Median
# * Median, in statistics, is the middle value of the given list of data, when arranged in an order. The arrangement of data or observations can be done either in ascending order or descending order.
#
# * In Maths, the median is also a type of average, which is used to find the center value. Therefore, it is also called measure of central tendency.

# %% [markdown]
# ### Median Formula
# $$
# Med(X) = \left\{
#     \begin{array}\\
#         X \left[ \frac{n}{2} \right] \ & \ if \ n \ is \ even \\
#          \frac{\left(X\left[\frac{n-1}{2}\right]+X \left[\frac{n+1}{2}\right]\right)}{2} \ & \ if \ n \ is \ odd \\
#     \end{array}
# \right.
# $$

# %%
# Finding Median for the given data set

# %% [markdown]
# #### Median with inbulit function

# %%
data_median = {'Mthly_HH_Income':data['Mthly_HH_Income'].median(),'Mthly_HH_Expense':data['Mthly_HH_Expense'].median(),
   'Emi_or_Rent_Amt':data['Emi_or_Rent_Amt'].median(),'Annual_HH_Income':data['Annual_HH_Income'].median()}

# %%
data_median
# Out:
# {'Mthly_HH_Income': 35000.0,
#  'Mthly_HH_Expense': 15500.0,
#  'Emi_or_Rent_Amt': 0.0,
#  'Annual_HH_Income': 447420.0}

# %%
pd.DataFrame.from_dict(data_median,orient="index",columns=['median'])
# Out:
#                     median
# Mthly_HH_Income    35000.0
# Mthly_HH_Expense   15500.0
# Emi_or_Rent_Amt        0.0
# Annual_HH_Income  447420.0

# %% [markdown]
# #### Median without inbulit function

# %%
def med(lst):
    sortedLst = sorted(lst)
    lstLen = len(lst)
    index = (lstLen - 1) // 2
   
    if (lstLen % 2):
        return sortedLst[index]
    else:
        return (sortedLst[index] + sortedLst[index + 1])/2.0

# %%
Mthly_HH_Income = med(data['Mthly_HH_Income'])
Mthly_HH_Expense = med(data['Mthly_HH_Expense'])
Emi_or_Rent_Amt = med(data['Emi_or_Rent_Amt'])
Annual_HH_Income = med(data['Annual_HH_Income'])
data2 = [Mthly_HH_Income,Mthly_HH_Expense,Emi_or_Rent_Amt,Annual_HH_Income]
names =  ['Mthly_HH_Income','Mthly_HH_Expense','Emi_or_Rent_Amt','Annual_HH_Income']

# %%
pd.DataFrame(data2,index=names,columns=['mean'])
# Out:
#                       mean
# Mthly_HH_Income    35000.0
# Mthly_HH_Expense   15500.0
# Emi_or_Rent_Amt        0.0
# Annual_HH_Income  447420.0

# %% [markdown]
# ## What is Mode
# * A mode is defined as the value that has a higher frequency in a given set of values. It is the value that appears the most number of times

# %% [markdown]
# ### Mode Formula

# %% [markdown]
# $$ Mode Formula  = L + \frac{\left(f_m-f_1\right)\times h}{\left(f_m-f_1\right)+\left(f_m-f_2\right)} $$

# %% [markdown]
# #### Mode with inbuilt function

# %%
No_of_Fly_Members = data['No_of_Fly_Members'].mode()
No_of_Earning_Members= data['No_of_Earning_Members'].mode()
data3 = [No_of_Earning_Members,No_of_Fly_Members]
name3 = ['Mode of No_of_Earning_Members','Mode of No_of_Fly_Members']

# %%
mode = pd.DataFrame(data3,index = name3)

# %%
mode[0]
# Out:
# Mode of No_of_Earning_Members    1
# Mode of No_of_Fly_Members        4
# Name: 0, dtype: int64

# %% [markdown]
# #### Mode without inbuilt Function

# %%
from collections import Counter
def my_mode(sample):
    c = Counter(sample)
    return [k for k, v in c.items() if v == c.most_common(1)[0][1]]

# %%
No_of_Fly_Members = my_mode(data['No_of_Fly_Members'])
No_of_Earning_Members = my_mode(data['No_of_Earning_Members'])
data_3 = [No_of_Fly_Members,No_of_Earning_Members]

# %%
pd.DataFrame(data_3,index=name3,columns=['mode'])
# Out:
#                                mode
# Mode of No_of_Earning_Members     4
# Mode of No_of_Fly_Members         1

# %% [markdown]
# ### Variance
# * Variance is another number that indicates how spread out the values are.
#
# * In fact, if you take the square root of the variance, you get the standard deviation!
#
# * Or the other way around, if you multiply the standard deviation by itself, you get the variance!
#
# * To calculate the variance you have to do as follows:
#
# * 1. Find the mean:
#
# * 2. For each value: find the difference from the mean:
#
# * 3. For each difference: find the square value:
#
# * 4. The variance is the average number of these squared differences:

# %% [markdown]
# ### Variance Formula

# %% [markdown]
# $$  S^2 = \frac{\sum\left(x_i -\bar{x} \right)^2}{n-1}\\
# $$
#
# $
# S^2	=	sample \ variance \\
# x_i	=	the \ value \ of \  the \  one \ observation \\
# \bar{x}	=	the \ mean \ value \ of \ all \ observations \\
# n	=	the \ number \  of \ observations\\
# $

# %% [markdown]
# #### Variance with inbuilt function

# %%
Variance = np.var(data)
print(Variance)
# Out:
# Mthly_HH_Income          6.674788e+08
# Mthly_HH_Expense         1.432499e+08
# No_of_Fly_Members        2.256400e+00
# Emi_or_Rent_Amt          3.817640e+07
# Annual_HH_Income         1.004372e+11
# No_of_Earning_Members    5.284000e-01
# dtype: float64

# %% [markdown]
# #### Variance without inbuilt function

# %%
def variance(X):
    mean = sum(X)/len(X)
    tot = 0.0
    for x in X:
        tot = tot + (x - mean)**2
    return tot/len(X)

# %%
Mthly_HH_Income = variance(data['Mthly_HH_Income'])
Mthly_HH_Expense = variance(data['Mthly_HH_Expense'])
No_of_Fly_Members = variance(data['No_of_Fly_Members'])
Emi_or_Rent_Amt = variance(data['Emi_or_Rent_Amt'])
Annual_HH_Income = variance(data['Annual_HH_Income'])
No_of_Earning_Members = variance(data['No_of_Earning_Members'])
data_variance = [Mthly_HH_Income,Mthly_HH_Expense,No_of_Fly_Members,Emi_or_Rent_Amt,Annual_HH_Income,No_of_Earning_Members]
col_names = ['Mthly_HH_Income','Mthly_HH_Expense','No_of_Fly_Members','Emi_or_Rent_Amt','Annual_HH_Income','No_of_Earning_Members']

# %%
pd.DataFrame(data_variance,index= col_names,columns=['variance'])
# Out:
#                            variance
# Mthly_HH_Income        6.674788e+08
# Mthly_HH_Expense       1.432499e+08
# No_of_Fly_Members      2.256400e+00
# Emi_or_Rent_Amt        3.817640e+07
# Annual_HH_Income       1.004372e+11
# No_of_Earning_Members  5.284000e-01

# %% [markdown]
# ### What is Standard Deviation?
# * Standard deviation is a number that describes how spread out the values are.
#
# * A low standard deviation means that most of the numbers are close to the mean (average) value.
#
# * A high standard deviation means that the values are spread out over a wider range.

# %% [markdown]
# ### Standard Deviation Formula

# %% [markdown]
# $$ \sigma	= \sqrt{\frac{\sum\left(x_i - \mu\right)^2}{N}} $$
#
# $
# \sigma	=	population \ standard \ deviation \\
# N	=	the \ size \ of \ the \ population \\
# x_i	=	each \ value \ from \ the \ population \\
# \mu	=	the \ population \ mean \\
# $

# %% [markdown]
# #### Standard Deviation with inbuilt function

# %%
Standard_Deviation = np.std(data)
print(Standard_Deviation)
# Out:
# Mthly_HH_Income           25835.611779
# Mthly_HH_Expense          11968.704023
# No_of_Fly_Members             1.502132
# Emi_or_Rent_Amt            6178.705366
# Annual_HH_Income         316918.265315
# No_of_Earning_Members         0.726911
# dtype: float64

# %% [markdown]
# #### Standard Deviation without inbuilt function

# %%
def stdev(data):
    var = variance(data)
    std_dev = math.sqrt(var)
    return std_dev

# %%
Mthly_HH_Income = stdev(data['Mthly_HH_Income'])
Mthly_HH_Expense = stdev(data['Mthly_HH_Expense'])
No_of_Fly_Members = stdev(data['No_of_Fly_Members'])
Emi_or_Rent_Amt = stdev(data['Emi_or_Rent_Amt'])
Annual_HH_Income = stdev(data['Annual_HH_Income'])
No_of_Earning_Members = stdev(data['No_of_Earning_Members'])
data_stdev = [Mthly_HH_Income,Mthly_HH_Expense,No_of_Fly_Members,Emi_or_Rent_Amt,Annual_HH_Income,No_of_Earning_Members]
col_names = ['Mthly_HH_Income','Mthly_HH_Expense','No_of_Fly_Members','Emi_or_Rent_Amt','Annual_HH_Income','No_of_Earning_Members']

# %%
pd.DataFrame(data_stdev,index= col_names,columns=['stdev'])
# Out:
#                                stdev
# Mthly_HH_Income         25835.611779
# Mthly_HH_Expense        11968.704023
# No_of_Fly_Members           1.502132
# Emi_or_Rent_Amt          6178.705366
# Annual_HH_Income       316918.265315
# No_of_Earning_Members       0.726911

# %% [markdown]
# ## correlation

# %% [markdown]
# * What is correlation?
# Correlation is a statistical measure that expresses the extent to which two variables are linearly related (meaning they change together at a constant rate). It’s a common tool for describing simple relationships without making a statement about cause and effect.
#
# * How is correlation measured?
# The sample correlation coefficient, r, quantifies the strength of the relationship. Correlations are also tested for statistical significance.
#
# * What are some limitations of correlation analysis?
# Correlation can’t look at the presence or effect of other variables outside of the two being explored. Importantly, correlation doesn’t tell us about cause and effect. Correlation also cannot accurately describe curvilinear relationships.

# %% [markdown]
# ![0_abk24QJL8-9JKFEz.png](attachment:0_abk24QJL8-9JKFEz.png)

# %%
data.corr()
# Out:
#                        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  \
# Mthly_HH_Income               1.000000          0.649215           0.448317
# Mthly_HH_Expense              0.649215          1.000000           0.639702
# No_of_Fly_Members             0.448317          0.639702           1.000000
# Emi_or_Rent_Amt               0.036976          0.405280           0.085808
# Annual_HH_Income              0.970315          0.591222           0.430868
# No_of_Earning_Members         0.347883          0.311915           0.597482
#
#                        Emi_or_Rent_Amt  Annual_HH_Income  \
# Mthly_HH_Income               0.036976          0.970315
# Mthly_HH_Expense              0.405280          0.591222
# No_of_Fly_Members             0.085808          0.430868
# Emi_or_Rent_Amt               1.000000          0.002716
# Annual_HH_Income              0.002716          1.000000
# No_of_Earning_Members        -0.097431          0.296679
#
# ...

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
f, ax = plt.subplots(1,3, figsize = (20,5))
ax[0].scatter(data.Mthly_HH_Income,data.Annual_HH_Income)
ax[0].set_xlabel('Mthly_HH_Income')
ax[0].set_title('Mthly_HH_Income', size = 22)
ax[1].scatter(data.Mthly_HH_Expense,data.Annual_HH_Income)
ax[1].set_xlabel('Mthly_HH_Expense')
ax[1].set_title('Mthly_HH_Expense', size = 22)
ax[2].scatter(data.No_of_Earning_Members, data.Annual_HH_Income)
ax[2].set_xlabel('No_of_Earning_Members')
ax[2].set_title('No_of_Earning_Members', size = 22)
plt.show()

# %% [markdown]
# ### Normal Distribution

# %% [markdown]
# * The normal distribution is a form presenting data by arranging the probability distribution of each value in the data.Most values remain around the mean value making the arrangement symmetric.
#
# * We use various functions in numpy library to mathematically calculate the values for a normal distribution. Histograms are created over which we plot the probability distribution curve.

# %% [markdown]
# ![bell_curve_normal_distribution%20%281%29.jpg](attachment:bell_curve_normal_distribution%20%281%29.jpg)

# %% [markdown]
# ### Contents

# %% [markdown]
# ### Properties of Normal Distribution
# * Empirical Rule for Normal Distribution
# * What is a Standard Normal Distribution?
# * Getting Familiar with Skewed Distribution
# * 1) Left Skewed Distribution
# * 2) Right Skewed Distribution
# ### How to check the Normality of a Distribution
# * Histogram
# * KDE Plots
# * Q_Q Plots
# * Skewness
# * Kurtosis

# %% [markdown]
# ### Properties of Normal Distribution

# %% [markdown]
# ![Screenshot-from-2020-03-06-17-19-03.png](attachment:Screenshot-from-2020-03-06-17-19-03.png)

# %% [markdown]
# ![Screenshot-from-2020-03-06-17-19-07.png](attachment:Screenshot-from-2020-03-06-17-19-07.png)

# %% [markdown]
# * We call this Bell-shaped curve a Normal Distribution. Carl Friedrich Gauss discovered it so sometimes we also call it a Gaussian Distribution as well.
#
# * We can simplify the Normal Distribution’s Probability Density by using only two parameters: 𝝻 Mean and 𝛔2. This curve is symmetric around the Mean. Also as you can see for this distribution, the Mean, Median, and Mode are all the same.
#
# * One more important phenomena of a normal distribution is that it retains the normal shape throughout, unlike other probability distributions that change their properties after a transformation. For a Normal Distribution:
#
# *  Product of two Normal Distribution results into a Normal Distribution
# *  The Sum of two Normal Distributions is a Normal Distribution
# *  Convolution of two Normal Distribution is also a Normal Distribution
# *  Fourier Transformation of a Normal Distribution is also Normal

# %% [markdown]
# #### Plotting Uniform and Normal Distribution

# %%
sns.distplot(data['Mthly_HH_Income']);

# %%
sns.distplot(data['Mthly_HH_Expense']);

# %%
sns.distplot(data['No_of_Fly_Members'])
# Out:
# <AxesSubplot:xlabel='No_of_Fly_Members', ylabel='Density'>

# %%
sns.distplot(data['Annual_HH_Income'])
# Out:
# <AxesSubplot:xlabel='Annual_HH_Income', ylabel='Density'>

# %% [markdown]
# ### Empirical Rule for Normal Distribution

# %% [markdown]
# ![Screenshot-from-2020-03-06-17-26-30.png](attachment:Screenshot-from-2020-03-06-17-26-30.png)

# %% [markdown]
# According to the Empirical Rule for Normal Distribution:
#
# * 68.27% of data lies within 1 standard deviation of the mean
# * 95.45% of data lies within 2 standard deviations of the mean
# * 99.73% of data lies within 3 standard deviations of the mean
# * Thus, almost all the data lies within 3 standard deviations. This rule enables us to check for Outliers and is very helpful * * when determining the normality of any distribution.

# %%
mean = data['Mthly_HH_Expense'].mean()
SD = data['Mthly_HH_Expense'].std()
  
# value of cdf between one, two
# and three S.D. around the mean
one_sd = norm.cdf(SD, mean, SD) - norm.cdf(-SD, mean, SD)
two_sd = norm.cdf(2 * SD, mean, SD) - norm.cdf(-2 * SD, mean, SD)
three_sd = norm.cdf(3 * SD, mean, SD) - norm.cdf(-3 * SD, mean, SD)
  
# printing the value of fractions
# within each band
print("Fracton of values within one SD =", one_sd)
print("Fracton of values within two SD =", two_sd)
print("Fracton of values within three SD =", three_sd)
# Out:
# Fracton of values within one SD = 0.28365940376715687
# Fracton of values within two SD = 0.6711226361491088
# Fracton of values within three SD = 0.9255624809153865

# %% [markdown]
# ### What is a Standard Normal Distribution?

# %% [markdown]
# Standard Normal Distribution is a special case of Normal Distribution when 𝜇 = 0 and 𝜎  = 1. For any Normal distribution, we can convert it into Standard Normal distribution using the formula:

# %% [markdown]
# To understand the importance of converting Normal Distribution into Standard Normal Distribution,  let’s suppose there are two students: Ross and Rachel. Ross scored 65 in the exam of paleontology and Rachel scored 80 in the fashion designing exam.
#
# Can we conclude that Rachel scored better than Ross?
#
# No, because the way people performed in paleontology may be different from the way people performed in fashion designing. The variability may not be the same here.
#
# So, a direct comparison by just looking at the scores will not work.
#
# Now, let’s say the paleontology marks follow a normal distribution with mean 60 and a standard deviation of 4. On the other hand, the fashion designing marks follow a normal distribution with mean 79 and standard deviation of 2.
#
# We will have to calculate the z score by standardization of both these distributions:
#
#
#
# Thus, Ross scored 1.25 standard deviations above the mean score while Rachel scored only 0.5 standard deviations above the mean score. Hence we can say that Ross Performed better than Rachel.

# %% [markdown]
# ![Screenshot-from-2020-03-06-17-32-06.png](attachment:Screenshot-from-2020-03-06-17-32-06.png)

# %% [markdown]
# ![Screenshot-from-2020-03-06-17-32-14.png](attachment:Screenshot-from-2020-03-06-17-32-14.png)

# %% [markdown]
# ![Screenshot-from-2020-03-06-17-33-00.png](attachment:Screenshot-from-2020-03-06-17-33-00.png)

# %% [markdown]
# ### Conclusion
#
# Thus, Ross scored 1.25 standard deviations above the mean score while Rachel scored only 0.5 standard deviations above the mean score. Hence we can say that Ross Performed better than Rachel.

# %% [markdown]
# ### Skewed Distribution
#
# Normal Distribution is symmetric, which means its tails on one side are the mirror image of the other side. But this is not the case with most datasets. Generally, data points cluster on one side more than the other. We call these types of distributions Skewed Distributions.
#
# ![grafskewness.gif](attachment:grafskewness.gif)

# %% [markdown]
# ### Left Skewed Distribution
#
# When data points cluster on the right side of the distribution, then the tail would be longer on the left side. This is the property of Left Skewed Distribution. The tail is longer in the negative direction so we also call it Negatively Skewed Distribution.

# %% [markdown]
# ![Screenshot-from-2020-03-06-18-22-42.png](attachment:Screenshot-from-2020-03-06-18-22-42.png)

# %% [markdown]
# Here, Mode > Median > Mean.
#
# In the Normal Distribution, Mean, Median and Mode are equal but in a negatively skewed distribution, we express the general relationship between the central tendency measured as:
#
# Mode > Median > Mean

# %% [markdown]
# ### Right Skewed Distribution
#
# When data points cluster on the left side of the distribution, then the tail would be longer on the right side. This is the property of Right Skewed Distribution. Here, the tail is longer in the positive direction so we also call it Positively Skewed Distribution.

# %% [markdown]
# ![Screenshot-from-2020-03-12-14-02-09.png](attachment:Screenshot-from-2020-03-12-14-02-09.png)

# %% [markdown]
# In a positively skewed distribution, we express the general relationship between the central tendency measures as:
#
# Mode < Median < Mean

# %% [markdown]
# ### Skewness

# %% [markdown]
# * Skewness is also another measure to check for normality which tells us the amount and direction of the skewed data points. Generally for the value of Skewness:
#
# * If the value is less than -0.5, we consider the distribution to be negatively skewed or left-skewed where data points cluster on the right side and the tails are longer on the left side of the distribution
# * Whereas if the value is greater than 0.5, we consider the distribution to be positively skewed or right-skewed where data points cluster on the left side and the tails are longer on the right side of the distribution
# * And finally, if the value is between -0.5 and 0.5, we consider the distribution to be approximately symmetric

# %%
data.skew()
# Out:
# Mthly_HH_Income          0.924615
# Mthly_HH_Expense         1.199461
# No_of_Fly_Members        0.113674
# Emi_or_Rent_Amt          3.403680
# Annual_HH_Income         1.192949
# No_of_Earning_Members    1.593301
# dtype: float64

# %% [markdown]
# ### Kurtosis

# %% [markdown]
# * Another numerical measure to check for Normality is Kurtosis. Kurtosis gives the information regarding tailedness which basically indicates the data distribution along the tails.

# %% [markdown]
# * For the symmetric type of distribution, the Kurtosis value will be close to Zero. We call such types of distributions as Mesokurtic distribution. Its tails are similar to Gaussian Distribution.
#
# ![Screenshot-from-2020-03-11-11-12-18.png](attachment:Screenshot-from-2020-03-11-11-12-18.png)

# %% [markdown]
# * If there are extreme values present in the data, then it means that more data points will lie along with the tails. In such cases, the value of K will be greater than zero. Here, Tail will be fatter and will have longer distribution. We call such types of distributions as Leptokurtic Distribution. As we can clearly see here, the tails are fatter and denser as compared to Gaussian Distribution:
#
# ![Screenshot-from-2020-03-11-11-12-56.png](attachment:Screenshot-from-2020-03-11-11-12-56.png)

# %% [markdown]
# * If there is a low presence of extreme values compared to Normal Distribution, then lesser data points will lie along the tail. In such cases, the Kurtosis value will be less than zero. We call such types of distributions as Platykurtic Distribution. It will have a thinner tail and a shorter distribution in comparison to Normal distribution.
#
# ![Screenshot-from-2020-03-11-11-13-49.png](attachment:Screenshot-from-2020-03-11-11-13-49.png)

# %%
data.kurtosis()
# Out:
# Mthly_HH_Income           0.115550
# Mthly_HH_Expense          0.942490
# No_of_Fly_Members        -0.851445
# Emi_or_Rent_Amt          14.202523
# Annual_HH_Income          1.101291
# No_of_Earning_Members     2.093212
# dtype: float64

# %% [markdown]
# # Q_Q Plot
#
# Quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities or dividing the observations in a sample in the same way.
#
# * 2 quantile is known as the Median
# * 4 quantile is known as the Quartile
# * 10 quantile is known as the Decile
# * 100 quantile is known as the Percentile

# %% [markdown]
# ![Screenshot-from-2020-03-11-11-07-49.png](attachment:Screenshot-from-2020-03-11-11-07-49.png)

# %% [markdown]
# #### Q_Q plot before Box Cox Transformation

# %%
stats.probplot(data['Mthly_HH_Income'], dist="norm", plot=plt)

plt.grid()

# %% [markdown]
# #### Q_Q plot after LogTransformation

# %%
stats.probplot(log_data['Mthly_HH_Income'], dist="norm", plot=plt)

plt.grid()

# %% [markdown]
# #### Q_Q plot after Box Cox Transformation

# %%
x_t, l = stats.boxcox(data['Mthly_HH_Income'])

print(l)
# Out:
# 0.3031376789702236

# %%
stats.probplot(x_t, dist="norm", plot=plt)

plt.grid()

# %% [markdown]
# ### Box Cox Transformation
#
# A Box Cox transformation is a transformation of a non-normal dependent variables into a normal shape. Normality is an important assumption for many statistical techniques; if your data isn’t normal, applying a Box-Cox means that you are able to run a broader number of tests.

# %% [markdown]
# ![trans3.png](attachment:trans3.png)

# %% [markdown]
# ![1_LXuBIQBworBtFub0lxpSTg.png](attachment:1_LXuBIQBworBtFub0lxpSTg.png)

# %%
sns.pairplot(data,diag_kind='kde');

# %%
data.skew()
# Out:
# Mthly_HH_Income          0.924615
# Mthly_HH_Expense         1.199461
# No_of_Fly_Members        0.113674
# Emi_or_Rent_Amt          3.403680
# Annual_HH_Income         1.192949
# No_of_Earning_Members    1.593301
# dtype: float64

# %% [markdown]
# ### Perform Feature Normalization - Log Transformation

# %%
Mthly_HH_Income_log = np.log(data['Mthly_HH_Income']+0.01) #can't take log(0) and so add a small number
Mthly_HH_Expense_log = np.log(data['Mthly_HH_Expense']+0.1)
No_of_Fly_Members_log = np.log(data['No_of_Fly_Members']+0.1)
Emi_or_Rent_Amt_log = np.log(data['Emi_or_Rent_Amt']+0.1)
Annual_HH_Income_log = np.log(data['Annual_HH_Income']+0.1)
No_of_Earning_Members_log = np.log(data['Mthly_HH_Income']+0.1)

# %%
log_data = pd.DataFrame({'Mthly_HH_Income': Mthly_HH_Income_log,'Mthly_HH_Expense': Mthly_HH_Expense_log,'No_of_Fly_Members': No_of_Fly_Members_log,
                        'Emi_or_Rent_Amt': Emi_or_Rent_Amt_log,'Annual_HH_Income': Annual_HH_Income_log,'No_of_Earning_Members': No_of_Earning_Members_log})
log_data.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0         8.517195          8.987209           1.131402         7.600952
# 1         8.699516          8.853680           0.741937         8.006401
# 2         9.210341          8.411855           0.741937        -2.302585
# 3         9.210341          7.600952           0.095310        -2.302585
# 4         9.433485          9.392670           0.741937         8.006401
#
#    Annual_HH_Income  No_of_Earning_Members
# 0         11.069760               8.517213
# 1         11.288783               8.699531
# 2         11.633373               9.210350
# 3         11.484527               9.210350
# 4         11.898189               9.433492

# %%
log_data.skew()
# Out:
# Mthly_HH_Income         -0.589852
# Mthly_HH_Expense        -0.402751
# No_of_Fly_Members       -0.723535
# Emi_or_Rent_Amt          0.452853
# Annual_HH_Income        -0.491175
# No_of_Earning_Members   -0.589843
# dtype: float64

# %%
sns.pairplot(log_data,diag_kind='kde');

# %% [markdown]
# #### here we can observe change in the distributions by log transformation
